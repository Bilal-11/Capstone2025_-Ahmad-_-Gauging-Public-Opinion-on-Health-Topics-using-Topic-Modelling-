# %% [markdown]
# # Attempt 2

# %% [markdown]
# ## Node Generation

# %% [markdown]
# Node generation leverages the representation power of pre-trained language models. The task of node generation can be seen as a sequence-to-sequence task, with sequence of text as input and sequence of nodes as output.
#
# The pre-trained model used in the paper is T5 (by Raffel et al.). It converts all text-based NLP problems to text-to-text generation task. In our case, the sequence of text is the input, and the sequence of nodes will also be generated as a text sequence output.
#
# Two special tokens are added for this task:
# 1. `<NODE_SEP>`: to separate multi-word nodes easily.
# 2. `<NO_NODE>`: when the maximum number of nodes to be generated is set, after those many nodes are generated, the rest are filled with this token.

# %%
# !pip install sentencepiece
# Out:
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.11/dist-packages (0.2.0)

# %%
# !pip install xmltodict
# Out:
# Collecting xmltodict
#   Downloading xmltodict-0.14.2-py2.py3-none-any.whl.metadata (8.0 kB)
# Downloading xmltodict-0.14.2-py2.py3-none-any.whl (10.0 kB)
# Installing collected packages: xmltodict
# Successfully installed xmltodict-0.14.2

# %%
from transformers import T5Tokenizer

tokenizer = T5Tokenizer.from_pretrained('t5-small')
tokenizer.add_tokens('__no_node__')
tokenizer.add_tokens('__node_sep__')
# Out:
# tokenizer_config.json:   0%|          | 0.00/2.32k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# 1

# %%
from transformers import T5ForConditionalGeneration

model = T5ForConditionalGeneration.from_pretrained('t5-small')

ip = tokenizer("generate nodes: A pizza trailer business in Galway East set up in the depths of the pandemic lockdown has landed a major national restaurant award. Ugly Doughlicious – or Ugly D’s – trades at Yeats Lodge in Peterswell Friday to Sunday, and on Saturday mornings at the Ardrahan Farmers Market. Selling DIY at home pizza kits as well as pizzas cooked in a wood fired oven in the trailer, the business has proved popular with lovers of the Italian staple since it set up. Despite being up against some much larger and more established brands at the national finals of the Irish Restaurant Awards, Ugly D’s was named Innovator of the Year for Connacht. Born during family pizza nights in the Covid pandemic lockdowns, Michelle Creavan and Darren Hoare tried just about very oven pizza on the market before they began experimenting with their own dough recipes.",return_tensors="pt")
output =  model.generate(inputs=ip.input_ids,max_length=150,attention_mask=ip.attention_mask)
print(tokenizer.decode(output[0], skip_special_tokens=True))
# Out:
# config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/242M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# in the depths of the pandemic lockdown has landed a major national restaurant award. Ugly Doughlicious – or Ugly D’s – trades at Yeats Lodge in Peterswell. despite being up against some much larger and more established brands at the national finals of the Irish Restaurant Awards.

# %%
import torch
decoder_input_ids = torch.tensor([[model.config.decoder_start_token_id]])

output = model(input_ids=ip.input_ids,attention_mask=ip.attention_mask,decoder_input_ids=decoder_input_ids,output_hidden_states=True)
logits_nodes = output.logits
joint_features = output.decoder_hidden_states[-1]
logits_nodes.argmax(-1)
# Out:
# Passing a tuple of `past_key_values` is deprecated and will be removed in Transformers v4.48.0. You should pass an instance of `EncoderDecoderCache` instead, e.g. `past_key_values=EncoderDecoderCache.from_legacy_cache(past_key_values)`.
# tensor([[32099]])

# %%
import xmltodict
import pprint

with open('Airport.xml', 'r', encoding='utf-8') as file:
    my_xml = file.read()

my_dict = xmltodict.parse(my_xml)

airport = my_dict['benchmark']['entries']['entry']
airport[0].keys()
# Out:
# dict_keys(['@category', '@eid', '@shape', '@shape_type', '@size', 'originaltripleset', 'modifiedtripleset', 'lex'])

# %%
print(airport[0]['originaltripleset']['otriple'])
print(airport[0]['modifiedtripleset']['mtriple'])
print(airport[0]['lex'][0]['#text'])
# Out:
# ['Aarhus | leaderName | Jacob_Bundsgaard', 'Aarhus_Airport | city | Aarhus']
# ['Aarhus | leader | Jacob_Bundsgaard', 'Aarhus_Airport | cityServed | Aarhus']
# Aarhus airport serves the city of Aarhus whose leader is Jacob Bundsgaard.

# %%
len(airport)
# Out:
# 193

# %%
import xmltodict

# Extract subject and object from triple
def get_sub_obj(triple_text,sep):
  components = triple_text.split(sep)
  sub = components[0].strip().replace('_',' ')
  obj = components[2].strip().replace('_',' ')

  # How about train it on the whole triples
  pred = components[1].strip().replace('_',' ')
  return (sub,pred,obj)
  # return (sub,obj)

# xml_doc: xml filename with .xml extension
def get_input_target_pairs(xml_doc,node_sep):
  with open(xml_doc, 'r', encoding='utf-8') as file:
    xml_text = file.read()

  pairs = []
  topics = xmltodict.parse(xml_text)['benchmark']['entries']['entry']
  for topic in topics:
    # target nodes extraction
    otriple = topic['originaltripleset']
    target_nodes = []
    if isinstance(otriple,list):
      for otriplemini in otriple:
        triple_data = otriplemini['otriple']
        if isinstance(triple_data, list):
            target_nodes.extend(triple_data)
        else:
            target_nodes.append(triple_data)
    else:
      triple_data = otriple['otriple']
      if isinstance(triple_data, list):
        target_nodes.extend(triple_data)
      else:
        target_nodes.append(triple_data)

    seps_added = []
    for trip_str in target_nodes:
      seps_added.append(node_sep.join(get_sub_obj(trip_str,sep='|')))

    target_nodes = seps_added

    # input text extraction
    lex = topic['lex']
    input_texts = []
    if isinstance(lex,list):
      for lexmini in lex:
        input_texts.append(lexmini['#text'])
    else:
      input_texts.append(lex['#text'])

    for input_text in input_texts:
      temp_dict = {
          'input':'generate_triples:'+input_text,
          'output': target_nodes
      }
      pairs.append(temp_dict)

  return pairs

# %%
airport_dataset = get_input_target_pairs('Airport.xml','__sep__')

# %%
import json

with open('Airport.json','w',encoding='utf-8') as file:
  file.write(json.dumps(airport_dataset,indent=4))

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import xmltodict

artist_xml_file = '/content/drive/MyDrive/webnlg-train/Artist.xml'
artist_dataset = get_input_target_pairs(artist_xml_file,'__sep__')

# %%
import json

with open('Artist.json','w',encoding='utf-8') as file:
  file.write(json.dumps(artist_dataset,indent=4))

# %%
airport_dataset.extend(artist_dataset)

# %%
import random

random.shuffle(airport_dataset)
print(airport_dataset)
# Out:
# [{'input': 'generate_triples:Albennie Jones is a performer of rhythm and blues which is a music genre which has a disco derivative.', 'output': ['Albennie Jones__sep__genre__sep__Rhythm and blues', 'Rhythm and blues__sep__derivative__sep__Disco', 'Albennie Jones__sep__genre__sep__Rhythm and blues', 'Rhythm and blues__sep__derivatives__sep__Disco']}, {'input': 'generate_triples:Indie rock musician Aaron Deer is a soloist singer.', 'output': ['Aaron Deer__sep__genre__sep__Indie rock', 'Aaron Deer__sep__background__sep__"solo singer"@en', 'Aaron Deer__sep__genre__sep__Indie rock', 'Aaron Deer__sep__background__sep__"solo singer"']}, {'input': 'generate_triples:Aaron Deer is American from Indianapolis.', 'output': ['Aaron Deer__sep__hometown__sep__United States', 'Aaron Deer__sep__origin__sep__Indianapolis', 'Aaron Deer__sep__hometown__sep__Indianapolis', 'Aaron Deer__sep__origin__sep__United States']}, {'input': 'generate_triples:Andrew Rayel is associated with the musician Jwaydan Moyine who is associated with the musical artist John Digweed.', 'output': ['Jwaydan Moyine__sep__associatedMusicalArtist__sep__John Digweed', 'Andrew Rayel__sep__associatedBand__sep__Jwaydan Moyine', 'Andrew Rayel__sep__associatedMusicalArtist__sep__Jwaydan Moyine', 'Jwaydan Moyine__sep__associatedBand__sep__John Digweed']}, {'input': "generate_triples:Alan Frews' musical genre is rock music which originated from blues music.", 'output': ['Alan Frew__sep__genre__sep__Rock music', 'Rock music__sep__stylisticOrigins__sep__Blues', 'Alan Frew__sep__genre__sep__Rock music', 'Rock music__sep__stylisticOrigin__sep__Blues']}, {'input': 'generate_triples:Electropop is the musical genre of Ace Wilder and originated from disco.', 'output': ['Electropop__sep__stylisticOrigins__sep__Disco', 'Ace Wilder__sep__genre__sep__Electropop', 'Ace Wilder__sep__genre__sep__Electropop', 'Electropop__sep__stylisticOrigin__sep__Disco']}, {'input': 'generate_triples:Lake Placid, New York is part of Essex County, NY and it is served by the Adirondack Regional Airport.', 'output': ['Lake Placid, New York__sep__isPartOf__sep__Essex County, New York', 'Adirondack Regional Airport__sep__city__sep__Lake Placid, New York', 'Lake Placid, New York__sep__isPartOf__sep__Essex County, New York', 'Adirondack Regional Airport__sep__cityServed__sep__Lake Placid, New York']}, {'input': 'generate_triples:Al Anderson, who performs Country music, was in the band NRBQ and one played with The Wildweeds.', 'output': ['Al Anderson (NRBQ)__sep__associatedMusicalArtist__sep__The Wildweeds', 'Al Anderson (NRBQ)__sep__genre__sep__Country music', 'Al Anderson (NRBQ)__sep__associatedBand__sep__The Wildweeds', 'Al Anderson (NRBQ)__sep__genre__sep__Country music']}, {'input': 'generate_triples:Alderney Airport has a runway with a length of 733.0 metres and its 1st runway is made from Poaceae.', 'output': ['Alderney Airport__sep__r1Surface__sep__Poaceae', 'Alderney Airport__sep__runwayLength__sep__"733.044"^^xsd:double']}, {'input': 'generate_triples:Ace Wilder performs electropop music which has its origins in Disco.', 'output': ['Electropop__sep__stylisticOrigins__sep__Disco', 'Ace Wilder__sep__genre__sep__Electropop', 'Ace Wilder__sep__genre__sep__Electropop', 'Electropop__sep__stylisticOrigin__sep__Disco']}, {'input': 'generate_triples:Allama Iqbal International airport is located in Pakistan and the runway length is 3310.0.', 'output': ['Allama Iqbal International Airport__sep__location__sep__Pakistan', 'Allama Iqbal International Airport__sep__runwayLength__sep__"3310.0"^^xsd:double']}, {'input': 'generate_triples:Alfred Garth Jones died in Sidcup, London.', 'output': ['Alfred Garth Jones__sep__placeOfDeath__sep__London', 'Alfred Garth Jones__sep__deathPlace__sep__Sidcup']}, {'input': 'generate_triples:Chameleon Circuit member Alex Day has collaborated with artist Charlie McDonnell.', 'output': ['Alex Day__sep__associatedMusicalArtist__sep__Chameleon Circuit (band)', 'Alex Day__sep__associatedBand__sep__ ...

# %%
import json

with open('Flyartist.json','w',encoding='utf-8') as file:
  file.write(json.dumps(airport_dataset,indent=4))

# %%
import os
import json
import random

training_dir = '/content/drive/MyDrive/webnlg-train'
xml_files = []
master_dataset = []
for (root,dirs,file) in os.walk(training_dir):
  xml_files = file

for xml_file in xml_files:
  dataset = get_input_target_pairs(training_dir+'/'+xml_file,'__sep__')
  print(xml_file+':'+str(len(dataset)))
  master_dataset.extend(dataset)

random.shuffle(master_dataset)
print('---')
print('Master_dataset'+':'+str(len(master_dataset)))
# Out:
# Artist.xml:642
# City.xml:500
# Monument.xml:101
# WrittenWork.xml:554
# Airport.xml:491
# Athlete.xml:534
# Politician.xml:702
# Food.xml:760
# University.xml:105
# Company.xml:232
# CelestialBody.xml:360
# MeanOfTransportation.xml:611
# Building.xml:451
# Astronaut.xml:194
# SportsTeam.xml:498
# ComicsCharacter.xml:213
# ---
# Master_dataset:6948

# %%
import json

with open('Master_dataset.json','w',encoding='utf-8') as file:
  file.write(json.dumps(master_dataset,indent=4))

# %%
test_dataset = get_input_target_pairs('rdf-to-text-generation-test-data-with-refs-en.xml','__sep__')

# %%
import json

with open('Test_dataset.json','w',encoding='utf-8') as file:
  file.write(json.dumps(test_dataset,indent=4))
