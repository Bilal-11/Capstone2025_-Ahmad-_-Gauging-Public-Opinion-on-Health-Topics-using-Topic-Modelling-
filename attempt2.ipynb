# %% [markdown]
# # Attempt 2

# %% [markdown]
# ## Node Generation

# %% [markdown]
# Node generation leverages the representation power of pre-trained language models. The task of node generation can be seen as a sequence-to-sequence task, with sequence of text as input and sequence of nodes as output.
#
# The pre-trained model used in the paper is T5 (by Raffel et al.). It converts all text-based NLP problems to text-to-text generation task. In our case, the sequence of text is the input, and the sequence of nodes will also be generated as a text sequence output.
#
# Two special tokens are added for this task:
# 1. `<NODE_SEP>`: to separate multi-word nodes easily.
# 2. `<NO_NODE>`: when the maximum number of nodes to be generated is set, after those many nodes are generated, the rest are filled with this token.

# %%
# !pip install sentencepiece
# Out:
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.11/dist-packages (0.2.0)

# %%
# !pip install xmltodict
# Out:
# Collecting xmltodict
#   Downloading xmltodict-0.14.2-py2.py3-none-any.whl.metadata (8.0 kB)
# Downloading xmltodict-0.14.2-py2.py3-none-any.whl (10.0 kB)
# Installing collected packages: xmltodict
# Successfully installed xmltodict-0.14.2

# %%
from transformers import T5Tokenizer

tokenizer = T5Tokenizer.from_pretrained('t5-small')
tokenizer.add_tokens('__no_node__')
tokenizer.add_tokens('__node_sep__')
# Out:
# tokenizer_config.json:   0%|          | 0.00/2.32k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# 1

# %%
from transformers import T5ForConditionalGeneration

model = T5ForConditionalGeneration.from_pretrained('t5-small')

ip = tokenizer("generate nodes: A pizza trailer business in Galway East set up in the depths of the pandemic lockdown has landed a major national restaurant award. Ugly Doughlicious – or Ugly D’s – trades at Yeats Lodge in Peterswell Friday to Sunday, and on Saturday mornings at the Ardrahan Farmers Market. Selling DIY at home pizza kits as well as pizzas cooked in a wood fired oven in the trailer, the business has proved popular with lovers of the Italian staple since it set up. Despite being up against some much larger and more established brands at the national finals of the Irish Restaurant Awards, Ugly D’s was named Innovator of the Year for Connacht. Born during family pizza nights in the Covid pandemic lockdowns, Michelle Creavan and Darren Hoare tried just about very oven pizza on the market before they began experimenting with their own dough recipes.",return_tensors="pt")
output =  model.generate(inputs=ip.input_ids,max_length=150,attention_mask=ip.attention_mask)
print(tokenizer.decode(output[0], skip_special_tokens=True))
# Out:
# config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/242M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# in the depths of the pandemic lockdown has landed a major national restaurant award. Ugly Doughlicious – or Ugly D’s – trades at Yeats Lodge in Peterswell. despite being up against some much larger and more established brands at the national finals of the Irish Restaurant Awards.

# %%
import torch
decoder_input_ids = torch.tensor([[model.config.decoder_start_token_id]])

output = model(input_ids=ip.input_ids,attention_mask=ip.attention_mask,decoder_input_ids=decoder_input_ids,output_hidden_states=True)
logits_nodes = output.logits
joint_features = output.decoder_hidden_states[-1]
logits_nodes.argmax(-1)
# Out:
# Passing a tuple of `past_key_values` is deprecated and will be removed in Transformers v4.48.0. You should pass an instance of `EncoderDecoderCache` instead, e.g. `past_key_values=EncoderDecoderCache.from_legacy_cache(past_key_values)`.
# tensor([[32099]])

# %%
import xmltodict
import pprint

with open('Airport.xml', 'r', encoding='utf-8') as file:
    my_xml = file.read()

my_dict = xmltodict.parse(my_xml)

airport = my_dict['benchmark']['entries']['entry']
airport[0].keys()
# Out:
# dict_keys(['@category', '@eid', '@shape', '@shape_type', '@size', 'originaltripleset', 'modifiedtripleset', 'lex'])

# %%
print(airport[0]['originaltripleset']['otriple'])
print(airport[0]['modifiedtripleset']['mtriple'])
print(airport[0]['lex'][0]['#text'])
# Out:
# ['Aarhus | leaderName | Jacob_Bundsgaard', 'Aarhus_Airport | city | Aarhus']
# ['Aarhus | leader | Jacob_Bundsgaard', 'Aarhus_Airport | cityServed | Aarhus']
# Aarhus airport serves the city of Aarhus whose leader is Jacob Bundsgaard.

# %%
len(airport)
# Out:
# 193

# %%
import xmltodict
from pathlib import Path

# Extract subject and object from triple
def get_sub_obj(triple_text,sep):
  components = triple_text.split(sep)
  sub = components[0].strip().replace('_',' ')
  obj = components[2].strip().replace('_',' ')
  return (sub,obj)

# xml_doc: xml filename with .xml extension
def get_input_target_pairs(xml_doc,node_sep):
  with open(xml_doc, 'r', encoding='utf-8') as file:
    xml_text = file.read()

  topics = xmltodict.parse(xml_text)['benchmark']['entries']['entry']
  for topic in topics:
    # target nodes extraction
    otriple = topic['originaltripleset']
    ot = ''
    if isinstance(otriple,list):
      for otriplemini in otriple:
        # print(otriplemini)
        ot = otriplemini
    else:
      # print(otriple)
      ot = otriple
    print(otriple)
    print(ot['otriple'])
    target_nodes = []
    for trip_str in ot['otriple']:
      target_nodes.append(node_sep.join(get_sub_obj(trip_str,sep='|')))
    # print(target_nodes)
    print('---')

    # input text extraction
    lex = topic['lex']
    input_texts = []
    if isinstance(lex,list):
      for lexmini in lex:
        input_texts.append(lexmini['#text'])
    else:
      input_texts.append(lex['#text'])
    # print(lex)
    # print(input_texts)
    # print('---')

# %%
get_input_target_pairs('Airport.xml','__node_sep__')
# Out:
# {'otriple': ['Aarhus | leaderName | Jacob_Bundsgaard', 'Aarhus_Airport | city | Aarhus']}
# ['Aarhus | leaderName | Jacob_Bundsgaard', 'Aarhus_Airport | city | Aarhus']
# ---
# {'otriple': ['Aarhus_Airport | location | Tirstrup', 'Tirstrup | country | Denmark']}
# ['Aarhus_Airport | location | Tirstrup', 'Tirstrup | country | Denmark']
# ---
# [{'otriple': ['Aarhus_Airport | location | Tirstrup', 'Tirstrup | isPartOf | Central_Denmark_Region']}, {'otriple': ['Aarhus_Airport | location | Tirstrup', 'Tirstrup | subdivisionName | Central_Denmark_Region']}]
# ['Aarhus_Airport | location | Tirstrup', 'Tirstrup | subdivisionName | Central_Denmark_Region']
# ---
# {'otriple': ['Aarhus_Airport | location | Tirstrup', 'Tirstrup | subdivisionName | Denmark']}
# ['Aarhus_Airport | location | Tirstrup', 'Tirstrup | subdivisionName | Denmark']
# ---
# [{'otriple': ['Aarhus_Airport | operator | "Aarhus Lufthavn A/S"@en', 'Aarhus_Airport | runwayLength | "2701.75"^^xsd:double']}, {'otriple': ['Aarhus_Airport | operator | "Aarhus Lufthavn A/S"@en', 'Aarhus_Airport | runwayLength | "2702.0"^^xsd:double']}]
# ['Aarhus_Airport | operator | "Aarhus Lufthavn A/S"@en', 'Aarhus_Airport | runwayLength | "2702.0"^^xsd:double']
# ---
# [{'otriple': ['Aarhus_Airport | operator | Aktieselskab', 'Aarhus_Airport | runwayLength | "2701.75"^^xsd:double']}, {'otriple': ['Aarhus_Airport | operator | Aktieselskab', 'Aarhus_Airport | runwayLength | "2702.0"^^xsd:double']}]
# ['Aarhus_Airport | operator | Aktieselskab', 'Aarhus_Airport | runwayLength | "2702.0"^^xsd:double']
# ---
# {'otriple': ['Aarhus_Airport | operator | Aktieselskab', 'Aarhus_Airport | runwayDesignation | "10L/28R"']}
# ['Aarhus_Airport | operator | Aktieselskab', 'Aarhus_Airport | runwayDesignation | "10L/28R"']
# ---
# {'otriple': ['Aarhus_Airport | operator | Aktieselskab', 'Aarhus_Airport | runwayDesignation | "10R/28L"']}
# ['Aarhus_Airport | operator | Aktieselskab', 'Aarhus_Airport | runwayDesignation | "10R/28L"']
# ---
# {'otriple': ['Aarhus_Airport | runwayLength | "2776.73"^^xsd:double', 'Aarhus_Airport | operator | "Aarhus Lufthavn A/S"@en']}
# ['Aarhus_Airport | runwayLength | "2776.73"^^xsd:double', 'Aarhus_Airport | operator | "Aarhus Lufthavn A/S"@en']
# ---
# {'otriple': ['Aarhus_Airport | runwayLength | "2776.73"^^xsd:double', 'Aarhus_Airport | operator | Aktieselskab']}
# ['Aarhus_Airport | runwayLength | "2776.73"^^xsd:double', 'Aarhus_Airport | operator | Aktieselskab']
# ---
# {'otriple': ['Aarhus_Airport | runwayLength | "2777.0"^^xsd:double', 'Aarhus_Airport | operator | Aktieselskab']}
# ['Aarhus_Airport | runwayLength | "2777.0"^^xsd:double', 'Aarhus_Airport | operator | Aktieselskab']
# ---
# [{'otriple': ['Abilene_Regional_Airport | r1LengthF | 3678', 'Abilene_Regional_Airport | elevation | "545.897"^^xsd:double']}, {'otriple': ['Abilene_Regional_Airport | r1LengthF | 3678', 'Abilene_Regional_Airport | elevation | "546.0"^^xsd:double']}]
# ['Abilene_Regional_Airport | r1LengthF | 3678', 'Abilene_Regional_Airport | elevation | "546.0"^^xsd:double']
# ---
# [{'otriple': ['Abilene_Regional_Airport | r1Surface | Asphalt', 'Abilene_Regional_Airport | elevation | "545.897"^^xsd:double']}, {'otriple': ['Abilene_Regional_Airport | r1Surface | Asphalt', 'Abilene_Regional_Airport | elevation | "546.0"^^xsd:double']}]
# ['Abilene_Regional_Airport | r1Surface | Asphalt', 'Abilene_Regional_Airport | elevation | "546.0"^^xsd:double']
# ---
# [{'otriple': ['Abilene_Regional_Airport | r3LengthF | 7202', 'Abilene_Regional_Airport | elevation | "545.897"^^xsd:double']}, {'otriple': ['Abilene_Regional_Airport | r3LengthF | 7202', 'Abilene_Regional_Airport | elevation | "546.0"^^xsd:double']}]
# ['Abilene_Regional_Airport | r3LengthF | 7202', 'Abilene_Regional_Airport | elevation | "546.0"^^xsd:double']
# ---
# [{'otriple': ['Abilene_Regional_Airport | city | Abilene,_Texas', 'Abilene,_Texas | country | United_States']}, {'otriple': ['Abilene_Regional_Airport | cityServed | Abilene,_Texas', 'Abilene,_Texas | country | United_States']}]
# ['Abilene_Regional_Airport | cityServed | Abilene,_Texas', 'Abilene,_Texas | country | United_States']
# ---
# [{'otriple': ['Abilene_Regional_Airport | city | Abilene,_Texas', 'Abilene,_Texas | isPartOf | Jones_County,_Texas']}, {'otriple': ['Abilene_Regional_Airport | cityServed | Abilene,_Texas', 'Abilene,_Texas | isPartOf | Jones_County,_Texas']}, {'otriple': ['Abilene_Regional_Airport | cityServed | Abilene,_Texas', 'Abilene,_Texas | subdivisionName | Jones_County,_Texas']}]
# ['Abilene_Regional_Airport | cityServed | Abilene,_Texas', 'Abilene,_Texas | subdivisionName | Jones_County,_Texas']
# ---
# [{'otriple': ['Abilene_Regional_Airport | cityServed | Abilene,_Texas', 'Abilene,_Texas | isPartOf | Taylor_County,_Texas']}, {'otriple': ['Abilene_Regional_Airport | cityServed | Abilene,_Texas', 'Abilene,_Texas | subdivisionName | Taylor_County,_Texas']}, {'otriple': ['Abilene_Regional_Airport | city | Abilene,_Texas', 'Abilene,_Texas | isPartOf | Taylor_County,_Texas']}]
# ['Abilene_Regional_Airport | city | Abilene,_Texas', 'Abilene,_Texas | isPartOf | Taylor_County,_Texas']
# ---
# [{'otriple': ['Abilene_Regional_Airport | faa | "ABI"@en', 'Abilene_Regional_Airport | elevation | "545.897"^^xsd:double']}, {'otriple': ['Abilene_Regional_Airport | faa | "ABI"@en', 'Abilene_Regional_Airport | elevation | "546.0"^^xsd:double']}]
# ['Abilene_Regional_Airport | faa | "ABI"@en', 'Abilene_Regional_Airport | elevation | "546.0"^^xsd:double']
# ---
# [{'otriple': ['Adirondack_Regional_Airport | r1LengthF | 6573', 'Adirondack_Regional_Airport | elevation | "506.882"^^xsd:double']}, {'otriple': ['Adirondack_Regional_Airport | r1LengthF | 6573', 'Adirondack_Regional_Airport | elevation | "507.0"^^xsd:double']}]
# ['Adirondack_Regional_Airport | r1LengthF | 6573', 'Adirondack_Regional_Airport | elevation | "507.0"^^xsd:double']
# ---
# [{'otriple': ['Adirondack_Regional_Airport | cityServed | Lake_Placid,_New_York', 'Adirondack_Regional_Airport | city | Saranac_Lake,_New_York']}, {'otriple': ['Adirondack_Regional_Airport | city | Lake_Placid,_New_York', 'Adirondack_Regional_Airport | cityServed | Saranac_Lake,_New_York']}]
# ['Adirondack_Regional_Airport | city | Lake_Placid,_New_York', 'Adirondack_Regional_Airport | cityServed | Saranac_Lake,_New_York']
# ---
# [{'otriple': ['Adirondack_Regional_Airport | location | Harrietstown,_New_York', 'Adirondack_Regional_Airport | elevation | "507.0"^^xsd:double']}, {'otriple': ['Adirondack_Regional_Airport | location | Harrietstown,_New_York', 'Adirondack_Regional_Airport | elevation | "506.882"^^xsd:double']}]
# ['Adirondack_Regional_Airport | location | Harrietstown,_New_York', 'Adirondack_Regional_Airport | elevation | "506.882"^^xsd:double']
# ---
# [{'otriple': ['Adirondack_Regional_Airport | faa | "SLK"@en', 'Adirondack_Regional_Airport | elevation | "506.882"^^xsd:double']}, {'otriple': ['Adirondack_Regional_Airport | faa | "SLK"@en', 'Adirondack_Regional_Airport | elevation | "507.0"^^xsd:double']}]
# ['Adirondack_Regional_Airport | faa | "SLK"@en', 'Adirondack_Regional_Airport | elevation | "507.0"^^xsd:double']
# ---
# {'otriple': ['Adolfo_Suárez_Madrid–Barajas_Airport | location | Alcobendas', 'Alcobendas | country | Spain']}
# ['Adolfo_Suárez_Madrid–Barajas_Airport | location | Alcobendas', 'Alcobendas | country | Spain']
# ---
# {'otriple': ['Adolfo_Suárez_Madrid–Barajas_Airport | location | Madrid', 'Madrid | country | Spain']}
# ['Adolfo_Suárez_Madrid–Barajas_Airport | location | Madrid', 'Madrid | country | Spain']
# ---
# {'otriple': ['Adolfo_Suárez_Madrid–Barajas_Airport | location | Paracuellos_de_Jarama', 'Adolfo_Suárez_Madrid–Barajas_Airport | elevation | "609.6"^^xsd:double']}
# ['Adolfo_Suárez_Madrid–Barajas_Airport | location | Paracuellos_de_Jarama', 'Adolfo_Suárez_Madrid–Barajas_Airport | elevation | "609.6"^^xsd:double']
# ---
# {'otriple': ['Adolfo_Suárez_Madrid–Barajas_Airport | location | Paracuellos_de_Jarama', 'Adolfo_Suárez_Madrid–Barajas_Airport | runwayLength | "3499.71"^^xsd:double']}
# ['Adolfo_Suárez_Madrid–Barajas_Airport | location | Paracuellos_de_Jarama', 'Adolfo_Suárez_Madrid–Barajas_Airport | runwayLength | "3499.71"^^xsd:double']
# ---
# {'otriple': ['Adolfo_Suárez_Madrid–Barajas_Airport | location | Paracuellos_de_Jarama', 'Adolfo_Suárez_Madrid–Barajas_Airport | runwayLength | "4100.0"^^xsd:double']}
# ['Adolfo_Suárez_Madrid–Barajas_Airport | location | Paracuellos_de_Jarama', 'Adolfo_Suárez_Madrid–Barajas_Airport | runwayLength | "4100.0"^^xsd:double']
# ---
# {'otriple': ['Adolfo_Suárez_Madrid–Barajas_Airport | location | Paracuellos_de_Jarama', 'Adolfo_Suárez_Madrid–Barajas_Airport | runwayLength | "4348.89"^^xsd:double']}
# ['Adolfo_Suárez_Madrid–Barajas_Airport | location | Paracuellos_de_Jarama', 'Adolfo_Suárez_Madrid–Barajas_Airport | runwayLength | "4348.89"^^xsd:double']
# ---
# {'otriple': ['Adolfo_Suárez_Madrid–Barajas_Airport | location | Paracuellos_de_Jarama', 'Paracuellos_de_Jarama | country | Spain']}
# ['Adolfo_Suárez_Madrid–Barajas_Airport | location | Paracuellos_de_Jarama', 'Paracuellos_de_Jarama | country | Spain']
# ---
# {'otriple': ['Adolfo_Suárez_Madrid–Barajas_Airport | location | Paracuellos_de_Jarama', 'Paracuellos_de_Jarama | isPartOf | Community_of_Madrid']}
# ['Adolfo_Suárez_Madrid–Barajas_Airport | location | Paracuellos_de_Jarama', 'Paracuellos_de_Jarama | isPartOf | Community_of_Madrid']
# ---
# {'otriple': ['Adolfo_Suárez_Madrid–Barajas_Airport | location | San_Sebastián_de_los_Reyes', 'San_Sebastián_de_los_Reyes | country | Spain']}
# ['Adolfo_Suárez_Madrid–Barajas_Airport | location | San_Sebastián_de_los_Reyes', 'San_Sebastián_de_los_Reyes | country | Spain']
# ---
# {'otriple': ['Adolfo_Suárez_Madrid–Barajas_Airport | runwayLength | "3499.71"^^xsd:double', 'Adolfo_Suárez_Madrid–Barajas_Airport | location | Madrid']}
# ['Adolfo_Suárez_Madrid–Barajas_Airport | runwayLength | "3499.71"^^xsd:double', 'Adolfo_Suárez_Madrid–Barajas_Airport | location | Madrid']
# ---
# {'otriple': ['Adolfo_Suárez_Madrid–Barajas_Airport | runwayLength | "4349.0"^^xsd:double', 'Adolfo_Suárez_Madrid–Barajas_Airport | location | "Madrid, Paracuellos de Jarama, San Sebastián de los Reyes and Alcobendas"@en']}
# ['Adolfo_Suárez_Madrid–Barajas_Airport | runwayLength | "4349.0"^^xsd:double', 'Adolfo_Suárez_Madrid–Barajas_Airport | location | "Madrid, Paracuellos de Jarama, San Sebastián de los Reyes and Alcobendas"@en']
# ---
# [{'otriple': ['Adolfo_Suárez_Madrid–Barajas_Airport | runwayLength | "4349.0"^^xsd:double', 'Adolfo_Suárez_Madrid–Barajas_Airport | location | San_Sebastián_de_los_Reyes']}, {'otriple': ['Adolfo_Suárez_Madrid–Barajas_Airport | runwayLength | "4348.89"^^xsd:double', 'Adolfo_Suárez_Madrid–Barajas_Airport | location | San_Sebastián_de_los_Reyes']}]
# ['Adolfo_Suárez_Madrid–Barajas_Airport | runwayLength | "4348.89"^^xsd:double', 'Adolfo_Suárez_Madrid–Barajas_Airport | location | San_Sebastián_de_los_Reyes']
# ---
# [{'otriple': ['Curitiba | isPartOf | Paraná_(state)', 'Afonso_Pena_International_Airport | city | Curitiba']}, {'otriple': ['Afonso_Pena_International_Airport | cityServed | Curitiba', 'Curitiba | subdivisionName | Paraná_(state)']}, {'otriple': ['Afonso_Pena_International_Airport | cityServed | Curitiba', 'Curitiba | isPartOf | Paraná_(state)']}]
# ['Afonso_Pena_International_Airport | cityServed | Curitiba', 'Curitiba | isPartOf | Paraná_(state)']
# ---
# [{'otriple': ['Afonso_Pena_International_Airport | cityServed | Curitiba', 'Curitiba | isPartOf | South_Region,_Brazil']}, {'otriple': ['Afonso_Pena_International_Airport | cityServed | Curitiba', 'Curitiba | subdivisionName | South_Region,_Brazil']}, {'otriple': ['Afonso_Pena_International_Airport | city | Curitiba', 'Curitiba | isPartOf | South_Region,_Brazil']}]
# ['Afonso_Pena_International_Airport | city | Curitiba', 'Curitiba | isPartOf | South_Region,_Brazil']
# ---
# [{'otriple': ['Afonso_Pena_International_Airport | elevationF | 2988', 'Afonso_Pena_International_Airport | location | São_José_dos_Pinhais']}, {'otriple': ['Afonso_Pena_International_Airport | elevationF | 2988', 'Afonso_Pena_International_Airport | location | "São José dos Pinhais, Brazil"@en']}]
# ['Afonso_Pena_International_Airport | elevationF | 2988', 'Afonso_Pena_International_Airport | location | "São José dos Pinhais, Brazil"@en']
# ---
# [{'otriple': ['Afonso_Pena_International_Airport | location | São_José_dos_Pinhais', 'Afonso_Pena_International_Airport | runwayLength | "1800.0"^^xsd:double']}, {'otriple': ['Afonso_Pena_International_Airport | location | São_José_dos_Pinhais', 'Afonso_Pena_International_Airport | runwayLength | "1799.84"^^xsd:double']}, {'otriple': ['Afonso_Pena_International_Airport | location | "São José dos Pinhais, Brazil"@en', 'Afonso_Pena_International_Airport | runwayLength | "1800.0"^^xsd:double']}, {'otriple': ['Afonso_Pena_International_Airport | location | "São José dos Pinhais, Brazil"@en', 'Afonso_Pena_International_Airport | runwayLength | "1799.84"^^xsd:double']}]
# ['Afonso_Pena_International_Airport | location | "São José dos Pinhais, Brazil"@en', 'Afonso_Pena_International_Airport | runwayLength | "1799.84"^^xsd:double']
# ---
# [{'otriple': ['Afonso_Pena_International_Airport | operator | Infraero', 'Afonso_Pena_International_Airport | location | São_José_dos_Pinhais']}, {'otriple': ['Afonso_Pena_International_Airport | operator | Infraero', 'Afonso_Pena_International_Airport | location | "São José dos Pinhais, Brazil"@en']}]
# ['Afonso_Pena_International_Airport | operator | Infraero', 'Afonso_Pena_International_Airport | location | "São José dos Pinhais, Brazil"@en']
# ---
# {'otriple': ['Afonso_Pena_International_Airport | operator | Infraero', 'Infraero | location | Brazil']}
# ['Afonso_Pena_International_Airport | operator | Infraero', 'Infraero | location | Brazil']
# ---
# [{'otriple': ['Afonso_Pena_International_Airport | runwayLength | "2215.0"^^xsd:double', 'Afonso_Pena_International_Airport | location | São_José_dos_Pinhais']}, {'otriple': ['Afonso_Pena_International_Airport | runwayLength | "2214.98"^^xsd:double', 'Afonso_Pena_International_Airport | location | São_José_dos_Pinhais']}, {'otriple': ['Afonso_Pena_International_Airport | runwayLength | "2215.0"^^xsd:double', 'Afonso_Pena_International_Airport | location | "São José dos Pinhais, Brazil"@en']}, {'otriple': ['Afonso_Pena_International_Airport | runwayLength | "2214.98"^^xsd:double', 'Afonso_Pena_International_Airport | location | "São José dos Pinhais, Brazil"@en']}]
# ['Afonso_Pena_International_Airport | runwayLength | "2214.98"^^xsd:double', 'Afonso_Pena_International_Airport | location | "São José dos Pinhais, Brazil"@en']
# ---
# {'otriple': ['Agra_Airport | iataLocationIdentifier | "AGR"', 'Agra_Airport | location | Agra']}
# ['Agra_Airport | iataLocationIdentifier | "AGR"', 'Agra_Airport | location | Agra']
# ---
# [{'otriple': ['Agra_Airport | icaoLocationIdentifier | "VIAG"', 'Agra_Airport | location | Agra']}, {'otriple': ['Agra_Airport | icaoLocationIdentifier | "(Location of airport in India)"', 'Agra_Airport | location | Agra']}]
# ['Agra_Airport | icaoLocationIdentifier | "(Location of airport in India)"', 'Agra_Airport | location | Agra']
# ---
# {'otriple': ['Agra_Airport | location | India', 'Agra_Airport | iataLocationIdentifier | "AGR"']}
# ['Agra_Airport | location | India', 'Agra_Airport | iataLocationIdentifier | "AGR"']
# ---
# [{'otriple': ['Agra_Airport | location | India', 'Agra_Airport | icaoLocationIdentifier | "(Location of airport in India)"']}, {'otriple': ['Agra_Airport | location | India', 'Agra_Airport | icaoLocationIdentifier | "VIAG"']}]
# ['Agra_Airport | location | India', 'Agra_Airport | icaoLocationIdentifier | "VIAG"']
# ---
# [{'otriple': ['Agra_Airport | location | India', 'India | leaderName | Narendra_Modi']}, {'otriple': ['Agra_Airport | location | India', 'India | leader | Narendra_Modi']}]
# ['Agra_Airport | location | India', 'India | leader | Narendra_Modi']
# ---
# {'otriple': ['Agra_Airport | location | Uttar_Pradesh', 'Agra_Airport | iataLocationIdentifier | "AGR"']}
# ['Agra_Airport | location | Uttar_Pradesh', 'Agra_Airport | iataLocationIdentifier | "AGR"']
# ---
# [{'otriple': ['Agra_Airport | location | Uttar_Pradesh', 'Agra_Airport | icaoLocationIdentifier | "(Location of airport in India)"']}, {'otriple': ['Agra_Airport | location | Uttar_Pradesh', 'Agra_Airport | icaoLocationIdentifier | "VIAG"']}]
# ['Agra_Airport | location | Uttar_Pradesh', 'Agra_Airport | icaoLocationIdentifier | "VIAG"']
# ---
# {'otriple': ['Agra_Airport | location | Uttar_Pradesh', 'Uttar_Pradesh | isPartOf | Bundelkhand']}
# ['Agra_Airport | location | Uttar_Pradesh', 'Uttar_Pradesh | isPartOf | Bundelkhand']
# ---
# {'otriple': ['Agra_Airport | location | Uttar_Pradesh', 'Uttar_Pradesh | leaderName | Ram_Naik']}
# ['Agra_Airport | location | Uttar_Pradesh', 'Uttar_Pradesh | leaderName | Ram_Naik']
# ---
# {'otriple': ['Agra_Airport | operator | Indian_Air_Force', 'Agra_Airport | location | Agra']}
# ['Agra_Airport | operator | Indian_Air_Force', 'Agra_Airport | location | Agra']
# ---
# {'otriple': ['Agra_Airport | operator | Indian_Air_Force', 'Indian_Air_Force | aircraftTransport | Boeing_C-17_Globemaster_III']}
# ['Agra_Airport | operator | Indian_Air_Force', 'Indian_Air_Force | aircraftTransport | Boeing_C-17_Globemaster_III']
# ---
# [{'otriple': ['Al-Taqaddum_Air_Base | cityServed | Fallujah', 'Al-Taqaddum_Air_Base | elevation | "83.82"^^xsd:double']}, {'otriple': ['Al-Taqaddum_Air_Base | city | Fallujah', 'Al-Taqaddum_Air_Base | elevation | "83.82"^^xsd:double']}]
# ['Al-Taqaddum_Air_Base | city | Fallujah', 'Al-Taqaddum_Air_Base | elevation | "83.82"^^xsd:double']
# ---
# [{'otriple': ['Al-Taqaddum_Air_Base | cityServed | Fallujah', 'Fallujah | country | Iraq']}, {'otriple': ['Fallujah | country | Iraq', 'Al-Taqaddum_Air_Base | city | Fallujah']}]
# ['Fallujah | country | Iraq', 'Al-Taqaddum_Air_Base | city | Fallujah']
# ---
# [{'otriple': ['Al-Taqaddum_Air_Base | runwayLength | "3684.0"^^xsd:double', 'Al-Taqaddum_Air_Base | city | Fallujah']}, {'otriple': ['Al-Taqaddum_Air_Base | runwayLength | "3684.12"^^xsd:double', 'Al-Taqaddum_Air_Base | cityServed | Fallujah']}, {'otriple': ['Al-Taqaddum_Air_Base | runwayLength | "3684.0"^^xsd:double', 'Al-Taqaddum_Air_Base | cityServed | Fallujah']}, {'otriple': ['Al-Taqaddum_Air_Base | runwayLength | "3684.12"^^xsd:double', 'Al-Taqaddum_Air_Base | city | Fallujah']}]
# ['Al-Taqaddum_Air_Base | runwayLength | "3684.12"^^xsd:double', 'Al-Taqaddum_Air_Base | city | Fallujah']
# ---
# [{'otriple': ['Al-Taqaddum_Air_Base | runwayLength | "4019.0"^^xsd:double', 'Al-Taqaddum_Air_Base | cityServed | Fallujah']}, {'otriple': ['Al-Taqaddum_Air_Base | runwayLength | "4019.09"^^xsd:double', 'Al-Taqaddum_Air_Base | city | Fallujah']}, {'otriple': ['Al-Taqaddum_Air_Base | runwayLength | "4019.0"^^xsd:double', 'Al-Taqaddum_Air_Base | city | Fallujah']}, {'otriple': ['Al-Taqaddum_Air_Base | runwayLength | "4019.09"^^xsd:double', 'Al-Taqaddum_Air_Base | cityServed | Fallujah']}]
# ['Al-Taqaddum_Air_Base | runwayLength | "4019.09"^^xsd:double', 'Al-Taqaddum_Air_Base | cityServed | Fallujah']
# ---
# {'otriple': ['Al_Asad_Airbase | location | "Al Anbar Province, Iraq"@en', 'Al_Asad_Airbase | runwayLength | "3078.48"^^xsd:double']}
# ['Al_Asad_Airbase | location | "Al Anbar Province, Iraq"@en', 'Al_Asad_Airbase | runwayLength | "3078.48"^^xsd:double']
# ---
# {'otriple': ['Al_Asad_Airbase | location | Iraq', 'Al_Asad_Airbase | elevationF | 618']}
# ['Al_Asad_Airbase | location | Iraq', 'Al_Asad_Airbase | elevationF | 618']
# ---
# {'otriple': ['Al_Asad_Airbase | location | Iraq', 'Al_Asad_Airbase | runwayLength | "3078.48"^^xsd:double']}
# ['Al_Asad_Airbase | location | Iraq', 'Al_Asad_Airbase | runwayLength | "3078.48"^^xsd:double']
# ---
# {'otriple': ['Al_Asad_Airbase | location | Iraq', 'Al_Asad_Airbase | runwayLength | "3090.0"^^xsd:double']}
# ['Al_Asad_Airbase | location | Iraq', 'Al_Asad_Airbase | runwayLength | "3090.0"^^xsd:double']
# ---
# {'otriple': ['Al_Asad_Airbase | location | Iraq', 'Al_Asad_Airbase | runwayLength | "3990.0"^^xsd:double']}
# ['Al_Asad_Airbase | location | Iraq', 'Al_Asad_Airbase | runwayLength | "3990.0"^^xsd:double']
# ---
# {'otriple': ['Al_Asad_Airbase | location | Iraq', 'Al_Asad_Airbase | runwayLength | "3992.88"^^xsd:double']}
# ['Al_Asad_Airbase | location | Iraq', 'Al_Asad_Airbase | runwayLength | "3992.88"^^xsd:double']
# ---
# {'otriple': ['Al_Asad_Airbase | operator | United_States_Air_Force', 'United_States_Air_Force | aircraftFighter | General_Dynamics_F-16_Fighting_Falcon']}
# ['Al_Asad_Airbase | operator | United_States_Air_Force', 'United_States_Air_Force | aircraftFighter | General_Dynamics_F-16_Fighting_Falcon']
# ---
# {'otriple': ['Al_Asad_Airbase | operator | United_States_Air_Force', 'United_States_Air_Force | aircraftFighter | McDonnell_Douglas_F-15_Eagle']}
# ['Al_Asad_Airbase | operator | United_States_Air_Force', 'United_States_Air_Force | aircraftFighter | McDonnell_Douglas_F-15_Eagle']
# ---
# {'otriple': ['Al_Asad_Airbase | operator | United_States_Air_Force', 'United_States_Air_Force | aircraftAttack | Lockheed_AC-130']}
# ['Al_Asad_Airbase | operator | United_States_Air_Force', 'United_States_Air_Force | aircraftAttack | Lockheed_AC-130']
# ---
# {'otriple': ['Al_Asad_Airbase | operator | United_States_Air_Force', 'United_States_Air_Force | battle | 1986_United_States_bombing_of_Libya']}
# ['Al_Asad_Airbase | operator | United_States_Air_Force', 'United_States_Air_Force | battle | 1986_United_States_bombing_of_Libya']
# ---
# {'otriple': ['Al_Asad_Airbase | operator | United_States_Air_Force', 'United_States_Air_Force | battle | Korean_War']}
# ['Al_Asad_Airbase | operator | United_States_Air_Force', 'United_States_Air_Force | battle | Korean_War']
# ---
# {'otriple': ['Al_Asad_Airbase | operator | United_States_Air_Force', 'United_States_Air_Force | aircraftTransport | Lockheed_C-130_Hercules']}
# ['Al_Asad_Airbase | operator | United_States_Air_Force', 'United_States_Air_Force | aircraftTransport | Lockheed_C-130_Hercules']
# ---
# {'otriple': ['Al_Asad_Airbase | runwayLength | "3990.0"^^xsd:double', 'Al_Asad_Airbase | location | "Al Anbar Province, Iraq"@en']}
# ['Al_Asad_Airbase | runwayLength | "3990.0"^^xsd:double', 'Al_Asad_Airbase | location | "Al Anbar Province, Iraq"@en']
# ---
# {'otriple': ['Al_Asad_Airbase | runwayLength | "3992.88"^^xsd:double', 'Al_Asad_Airbase | location | "Al Anbar Province, Iraq"@en']}
# ['Al_Asad_Airbase | runwayLength | "3992.88"^^xsd:double', 'Al_Asad_Airbase | location | "Al Anbar Province, Iraq"@en']
# ---
# {'otriple': ["Alcobendas | leaderParty | People's_Party_(Spain)", 'Adolfo_Suárez_Madrid–Barajas_Airport | location | Alcobendas']}
# ["Alcobendas | leaderParty | People's_Party_(Spain)", 'Adolfo_Suárez_Madrid–Barajas_Airport | location | Alcobendas']
# ---
# [{'otriple': ['Alderney_Airport | r1Surface | Asphalt', 'Alderney_Airport | city | Alderney']}, {'otriple': ['Alderney_Airport | cityServed | Alderney', 'Alderney_Airport | r1Surface | Asphalt']}]
# ['Alderney_Airport | cityServed | Alderney', 'Alderney_Airport | r1Surface | Asphalt']
# ---
# [{'otriple': ['Alderney_Airport | r1Surface | Poaceae', 'Alderney_Airport | city | Alderney']}, {'otriple': ['Alderney_Airport | r1Surface | Poaceae', 'Alderney_Airport | cityServed | Alderney']}]
# ['Alderney_Airport | r1Surface | Poaceae', 'Alderney_Airport | cityServed | Alderney']
# ---
# [{'otriple': ['Alderney_Airport | r1Surface | Poaceae', 'Alderney_Airport | runwayLength | "497.0"^^xsd:double']}, {'otriple': ['Alderney_Airport | r1Surface | Poaceae', 'Alderney_Airport | runwayLength | "497.129"^^xsd:double']}]
# ['Alderney_Airport | r1Surface | Poaceae', 'Alderney_Airport | runwayLength | "497.129"^^xsd:double']
# ---
# {'otriple': ['Alderney_Airport | r1Surface | Poaceae', 'Alderney_Airport | runwayLength | "733.044"^^xsd:double']}
# ['Alderney_Airport | r1Surface | Poaceae', 'Alderney_Airport | runwayLength | "733.044"^^xsd:double']
# ---
# {'otriple': ['Alderney_Airport | r1Surface | Poaceae', 'Poaceae | order | Commelinids']}
# ['Alderney_Airport | r1Surface | Poaceae', 'Poaceae | order | Commelinids']
# ---
# {'otriple': ['Alderney_Airport | r1Surface | Poaceae', 'Poaceae | order | Poales']}
# ['Alderney_Airport | r1Surface | Poaceae', 'Poaceae | order | Poales']
# ---
# [{'otriple': ['Alderney_Airport | cityServed | Alderney', 'Alderney | capital | Saint_Anne,_Alderney']}, {'otriple': ['Alderney_Airport | city | Alderney', 'Alderney | capital | Saint_Anne,_Alderney']}]
# ['Alderney_Airport | city | Alderney', 'Alderney | capital | Saint_Anne,_Alderney']
# ---
# {'otriple': ['Alderney_Airport | city | Alderney', 'Alderney | language | English_language']}
# ['Alderney_Airport | city | Alderney', 'Alderney | language | English_language']
# ---
# [{'otriple': ['Alderney_Airport | city | Alderney', 'Alderney | leaderName | Elizabeth_II']}, {'otriple': ['Alderney_Airport | cityServed | Alderney', 'Alderney | leaderName | Elizabeth_II']}, {'otriple': ['Alderney | leader | Elizabeth_II', 'Alderney_Airport | city | Alderney']}]
# ['Alderney | leader | Elizabeth_II', 'Alderney_Airport | city | Alderney']
# ---
# {'otriple': ['Alderney_Airport | runwayLength | "497.0"^^xsd:double', 'Alderney_Airport | r1Surface | Asphalt']}
# ['Alderney_Airport | runwayLength | "497.0"^^xsd:double', 'Alderney_Airport | r1Surface | Asphalt']
# ---
# {'otriple': ['Allama_Iqbal_International_Airport | location | Pakistan', 'Allama_Iqbal_International_Airport | operator | Pakistan_Civil_Aviation_Authority']}
# ['Allama_Iqbal_International_Airport | location | Pakistan', 'Allama_Iqbal_International_Airport | operator | Pakistan_Civil_Aviation_Authority']
# ---
# [{'otriple': ['Allama_Iqbal_International_Airport | location | Pakistan', 'Allama_Iqbal_International_Airport | runwayLength | "2900.0"^^xsd:double']}, {'otriple': ['Allama_Iqbal_International_Airport | location | Pakistan', 'Allama_Iqbal_International_Airport | runwayLength | "2899.87"^^xsd:double']}]
# ['Allama_Iqbal_International_Airport | location | Pakistan', 'Allama_Iqbal_International_Airport | runwayLength | "2899.87"^^xsd:double']
# ---
# {'otriple': ['Allama_Iqbal_International_Airport | location | Pakistan', 'Allama_Iqbal_International_Airport | runwayLength | "3310.0"^^xsd:double']}
# ['Allama_Iqbal_International_Airport | location | Pakistan', 'Allama_Iqbal_International_Airport | runwayLength | "3310.0"^^xsd:double']
# ---
# {'otriple': ['Allama_Iqbal_International_Airport | location | Pakistan', 'Allama_Iqbal_International_Airport | runwayLength | "3360.12"^^xsd:double']}
# ['Allama_Iqbal_International_Airport | location | Pakistan', 'Allama_Iqbal_International_Airport | runwayLength | "3360.12"^^xsd:double']
# ---
# {'otriple': ['Allama_Iqbal_International_Airport | location | Pakistan', 'Pakistan | leaderName | Mamnoon_Hussain']}
# ['Allama_Iqbal_International_Airport | location | Pakistan', 'Pakistan | leaderName | Mamnoon_Hussain']
# ---
# {'otriple': ['Allama_Iqbal_International_Airport | location | Pakistan', 'Pakistan | leaderName | Nawaz_Sharif']}
# ['Allama_Iqbal_International_Airport | location | Pakistan', 'Pakistan | leaderName | Nawaz_Sharif']
# ---
# {'otriple': ['Allama_Iqbal_International_Airport | location | Pakistan', 'Pakistan | leaderName | Sardar_Ayaz_Sadiq']}
# ['Allama_Iqbal_International_Airport | location | Pakistan', 'Pakistan | leaderName | Sardar_Ayaz_Sadiq']
# ---
# {'otriple': ['Allama_Iqbal_International_Airport | location | Punjab,_Pakistan', 'Allama_Iqbal_International_Airport | runwayLength | "3360.12"^^xsd:double']}
# ['Allama_Iqbal_International_Airport | location | Punjab,_Pakistan', 'Allama_Iqbal_International_Airport | runwayLength | "3360.12"^^xsd:double']
# ---
# {'otriple': ['Allama_Iqbal_International_Airport | location | Punjab,_Pakistan', 'Punjab,_Pakistan | leaderTitle | Provincial_Assembly_of_the_Punjab']}
# ['Allama_Iqbal_International_Airport | location | Punjab,_Pakistan', 'Punjab,_Pakistan | leaderTitle | Provincial_Assembly_of_the_Punjab']
# ---
# [{'otriple': ['Allama_Iqbal_International_Airport | operator | Pakistan_Civil_Aviation_Authority', 'Allama_Iqbal_International_Airport | location | "Punjab, Pakistan"@en']}, {'otriple': ['Allama_Iqbal_International_Airport | operator | Pakistan_Civil_Aviation_Authority', 'Allama_Iqbal_International_Airport | location | Punjab,_Pakistan']}]
# ['Allama_Iqbal_International_Airport | operator | Pakistan_Civil_Aviation_Authority', 'Allama_Iqbal_International_Airport | location | Punjab,_Pakistan']
# ---
# {'otriple': ['Allama_Iqbal_International_Airport | operator | Pakistan_Civil_Aviation_Authority', 'Pakistan_Civil_Aviation_Authority | location | Jinnah_International_Airport']}
# ['Allama_Iqbal_International_Airport | operator | Pakistan_Civil_Aviation_Authority', 'Pakistan_Civil_Aviation_Authority | location | Jinnah_International_Airport']
# ---
# [{'otriple': ['Allama_Iqbal_International_Airport | runwayLength | "3310.0"^^xsd:double', 'Allama_Iqbal_International_Airport | location | "Punjab, Pakistan"@en']}, {'otriple': ['Allama_Iqbal_International_Airport | location | Punjab,_Pakistan', 'Allama_Iqbal_International_Airport | runwayLength | "3310.0"^^xsd:double']}]
# ['Allama_Iqbal_International_Airport | location | Punjab,_Pakistan', 'Allama_Iqbal_International_Airport | runwayLength | "3310.0"^^xsd:double']
# ---
# [{'otriple': ['Alpena_County_Regional_Airport | r1LengthF | 9001', 'Alpena_County_Regional_Airport | elevation | "210.312"^^xsd:double']}, {'otriple': ['Alpena_County_Regional_Airport | r1LengthF | 9001', 'Alpena_County_Regional_Airport | elevation | "210.0"^^xsd:double']}]
# ['Alpena_County_Regional_Airport | r1LengthF | 9001', 'Alpena_County_Regional_Airport | elevation | "210.0"^^xsd:double']
# ---
# [{'otriple': ['Alpena_County_Regional_Airport | elevation | "210.312"^^xsd:double', 'Alpena_County_Regional_Airport | owner | Alpena_County,_Michigan']}, {'otriple': ['Alpena_County_Regional_Airport | elevation | "210.0"^^xsd:double', 'Alpena_County_Regional_Airport | owner | Alpena_County,_Michigan']}]
# ['Alpena_County_Regional_Airport | elevation | "210.0"^^xsd:double', 'Alpena_County_Regional_Airport | owner | Alpena_County,_Michigan']
# ---
# [{'otriple': ['Alpena_County_Regional_Airport | location | Maple_Ridge_Township,_Alpena_County,_Michigan', 'Alpena_County_Regional_Airport | elevation | "210.312"^^xsd:double']}, {'otriple': ['Alpena_County_Regional_Airport | location | Maple_Ridge_Township,_Alpena_County,_Michigan', 'Alpena_County_Regional_Airport | elevation | "210.0"^^xsd:double']}]
# ['Alpena_County_Regional_Airport | location | Maple_Ridge_Township,_Alpena_County,_Michigan', 'Alpena_County_Regional_Airport | elevation | "210.0"^^xsd:double']
# ---
# {'otriple': ['Alpena_County_Regional_Airport | location | Maple_Ridge_Township,_Alpena_County,_Michigan', 'Maple_Ridge_Township,_Alpena_County,_Michigan | country | United_States']}
# ['Alpena_County_Regional_Airport | location | Maple_Ridge_Township,_Alpena_County,_Michigan', 'Maple_Ridge_Township,_Alpena_County,_Michigan | country | United_States']
# ---
# [{'otriple': ['Alpena_County_Regional_Airport | location | Wilson_Township,_Alpena_County,_Michigan', 'Alpena_County_Regional_Airport | elevation | "210.312"^^xsd:double']}, {'otriple': ['Alpena_County_Regional_Airport | location | Wilson_Township,_Alpena_County,_Michigan', 'Alpena_County_Regional_Airport | elevation | "210.0"^^xsd:double']}]
# ['Alpena_County_Regional_Airport | location | Wilson_Township,_Alpena_County,_Michigan', 'Alpena_County_Regional_Airport | elevation | "210.0"^^xsd:double']
# ---
# {'otriple': ['Alpena_County_Regional_Airport | location | Wilson_Township,_Alpena_County,_Michigan', 'Wilson_Township,_Alpena_County,_Michigan | country | United_States']}
# ['Alpena_County_Regional_Airport | location | Wilson_Township,_Alpena_County,_Michigan', 'Wilson_Township,_Alpena_County,_Michigan | country | United_States']
# ---
# [{'otriple': ['Alpena_County_Regional_Airport | faa | "APN"@en', 'Alpena_County_Regional_Airport | elevation | "210.312"^^xsd:double']}, {'otriple': ['Alpena_County_Regional_Airport | faa | "APN"@en', 'Alpena_County_Regional_Airport | elevation | "210.0"^^xsd:double']}]
# ['Alpena_County_Regional_Airport | faa | "APN"@en', 'Alpena_County_Regional_Airport | elevation | "210.0"^^xsd:double']
# ---
# {'otriple': ['Amsterdam_Airport_Schiphol | r1Number | 18', 'Amsterdam_Airport_Schiphol | elevation | "-3.3528"^^xsd:double']}
# ['Amsterdam_Airport_Schiphol | r1Number | 18', 'Amsterdam_Airport_Schiphol | elevation | "-3.3528"^^xsd:double']
# ---
# {'otriple': ['Amsterdam_Airport_Schiphol | r4Surface | "Asphalt"@en', 'Amsterdam_Airport_Schiphol | elevation | "-3.3528"^^xsd:double']}
# ['Amsterdam_Airport_Schiphol | r4Surface | "Asphalt"@en', 'Amsterdam_Airport_Schiphol | elevation | "-3.3528"^^xsd:double']
# ---
# {'otriple': ['Amsterdam_Airport_Schiphol | r5Number | 18', 'Amsterdam_Airport_Schiphol | elevation | "-3.3528"^^xsd:double']}
# ['Amsterdam_Airport_Schiphol | r5Number | 18', 'Amsterdam_Airport_Schiphol | elevation | "-3.3528"^^xsd:double']
# ---
# {'otriple': ['Amsterdam_Airport_Schiphol | r5Surface | "Asphalt"@en', 'Amsterdam_Airport_Schiphol | elevation | "-3.3528"^^xsd:double']}
# ['Amsterdam_Airport_Schiphol | r5Surface | "Asphalt"@en', 'Amsterdam_Airport_Schiphol | elevation | "-3.3528"^^xsd:double']
# ---
# [{'otriple': ['Amsterdam | leaderName | Eberhard_van_der_Laan', 'Amsterdam_Airport_Schiphol | cityServed | Amsterdam']}, {'otriple': ['Amsterdam_Airport_Schiphol | city | Amsterdam', 'Amsterdam | leaderName | Eberhard_van_der_Laan']}]
# ['Amsterdam_Airport_Schiphol | city | Amsterdam', 'Amsterdam | leaderName | Eberhard_van_der_Laan']
# ---
# [{'otriple': ['Amsterdam_Airport_Schiphol | cityServed | Amsterdam', 'Amsterdam_Airport_Schiphol | runwayLength | "3400.0"^^xsd:double']}, {'otriple': ['Amsterdam_Airport_Schiphol | city | Amsterdam', 'Amsterdam_Airport_Schiphol | runwayLength | "3400.0"^^xsd:double']}]
# ['Amsterdam_Airport_Schiphol | city | Amsterdam', 'Amsterdam_Airport_Schiphol | runwayLength | "3400.0"^^xsd:double']
# ---
# {'otriple': ['Amsterdam_Airport_Schiphol | cityServed | Amsterdam', 'Amsterdam_Airport_Schiphol | runwayLength | "3453.0"^^xsd:double']}
# ['Amsterdam_Airport_Schiphol | cityServed | Amsterdam', 'Amsterdam_Airport_Schiphol | runwayLength | "3453.0"^^xsd:double']
# ---
# [{'otriple': ['Amsterdam_Airport_Schiphol | city | Amsterdam', 'Amsterdam_Airport_Schiphol | runwayLength | "3500.0"^^xsd:double']}, {'otriple': ['Amsterdam_Airport_Schiphol | cityServed | Amsterdam', 'Amsterdam_Airport_Schiphol | runwayLength | "3500.0"^^xsd:double']}]
# ['Amsterdam_Airport_Schiphol | cityServed | Amsterdam', 'Amsterdam_Airport_Schiphol | runwayLength | "3500.0"^^xsd:double']
# ---
# {'otriple': ['Amsterdam_Airport_Schiphol | cityServed | Amsterdam', 'Amsterdam_Airport_Schiphol | runwayLength | "3800.0"^^xsd:double']}
# ['Amsterdam_Airport_Schiphol | cityServed | Amsterdam', 'Amsterdam_Airport_Schiphol | runwayLength | "3800.0"^^xsd:double']
# ---
# {'otriple': ['Amsterdam_Airport_Schiphol | elevation | "-3.3528"^^xsd:double', 'Amsterdam_Airport_Schiphol | location | Haarlemmermeer']}
# ['Amsterdam_Airport_Schiphol | elevation | "-3.3528"^^xsd:double', 'Amsterdam_Airport_Schiphol | location | Haarlemmermeer']
# ---
# {'otriple': ['Andrews_County,_Texas | countySeat | Andrews,_Texas', 'Andrews_County_Airport | owner | Andrews_County,_Texas']}
# ['Andrews_County,_Texas | countySeat | Andrews,_Texas', 'Andrews_County_Airport | owner | Andrews_County,_Texas']
# ---
# {'otriple': ['Andrews_County,_Texas | largestCity | Andrews,_Texas', 'Andrews_County_Airport | owner | Andrews_County,_Texas']}
# ['Andrews_County,_Texas | largestCity | Andrews,_Texas', 'Andrews_County_Airport | owner | Andrews_County,_Texas']
# ---
# [{'otriple': ['Andrews_County_Airport | r3LengthF | 2939', 'Andrews_County_Airport | elevation | "967.435"^^xsd:double']}, {'otriple': ['Andrews_County_Airport | r3LengthF | 2939', 'Andrews_County_Airport | elevation | "973.0"^^xsd:double']}]
# ['Andrews_County_Airport | r3LengthF | 2939', 'Andrews_County_Airport | elevation | "973.0"^^xsd:double']
# ---
# [{'otriple': ['Andrews_County_Airport | r4LengthF | 25', 'Andrews_County_Airport | elevation | "973.0"^^xsd:double']}, {'otriple': ['Andrews_County_Airport | r4LengthF | 25', 'Andrews_County_Airport | elevation | "967.435"^^xsd:double']}]
# ['Andrews_County_Airport | r4LengthF | 25', 'Andrews_County_Airport | elevation | "967.435"^^xsd:double']
# ---
# [{'otriple': ['Andrews_County_Airport | location | Texas', 'Andrews_County_Airport | elevation | "973.0"^^xsd:double']}, {'otriple': ['Andrews_County_Airport | location | Texas', 'Andrews_County_Airport | elevation | "967.435"^^xsd:double']}]
# ['Andrews_County_Airport | location | Texas', 'Andrews_County_Airport | elevation | "967.435"^^xsd:double']
# ---
# {'otriple': ['Andrews_County_Airport | location | Texas', 'Texas | country | United_States']}
# ['Andrews_County_Airport | location | Texas', 'Texas | country | United_States']
# ---
# {'otriple': ['Andrews_County_Airport | location | Texas', 'Texas | demonym | Tejano']}
# ['Andrews_County_Airport | location | Texas', 'Texas | demonym | Tejano']
# ---
# {'otriple': ['Andrews_County_Airport | location | Texas', 'Texas | demonym | Texan']}
# ['Andrews_County_Airport | location | Texas', 'Texas | demonym | Texan']
# ---
# {'otriple': ['Andrews_County_Airport | location | Texas', 'Texas | language | English_language']}
# ['Andrews_County_Airport | location | Texas', 'Texas | language | English_language']
# ---
# {'otriple': ['Andrews_County_Airport | location | Texas', 'Texas | language | Spanish_language']}
# ['Andrews_County_Airport | location | Texas', 'Texas | language | Spanish_language']
# ---
# [{'otriple': ['Andrews_County_Airport | faa | "E11"@en', 'Andrews_County_Airport | elevation | "973.0"^^xsd:double']}, {'otriple': ['Andrews_County_Airport | faa | "E11"@en', 'Andrews_County_Airport | elevation | "967.435"^^xsd:double']}]
# ['Andrews_County_Airport | faa | "E11"@en', 'Andrews_County_Airport | elevation | "967.435"^^xsd:double']
# ---
# [{'otriple': ['Angola_International_Airport | r1LengthF | 13123', 'Angola_International_Airport | elevation | "159.106"^^xsd:double']}, {'otriple': ['Angola_International_Airport | r1LengthF | 13123', 'Angola_International_Airport | elevation | "159.0"^^xsd:double']}]
# ['Angola_International_Airport | r1LengthF | 13123', 'Angola_International_Airport | elevation | "159.0"^^xsd:double']
# ---
# [{'otriple': ['Angola_International_Airport | r1Number | 5', 'Angola_International_Airport | elevation | "159.0"^^xsd:double']}, {'otriple': ['Angola_International_Airport | r1Number | 5', 'Angola_International_Airport | elevation | "159.106"^^xsd:double']}]
# ['Angola_International_Airport | r1Number | 5', 'Angola_International_Airport | elevation | "159.106"^^xsd:double']
# ---
# [{'otriple': ['Angola_International_Airport | r1Surface | "ASPHALT"@en', 'Angola_International_Airport | elevation | "159.106"^^xsd:double']}, {'otriple': ['Angola_International_Airport | r1Surface | "ASPHALT"@en', 'Angola_International_Airport | elevation | "159.0"^^xsd:double']}]
# ['Angola_International_Airport | r1Surface | "ASPHALT"@en', 'Angola_International_Airport | elevation | "159.0"^^xsd:double']
# ---
# [{'otriple': ['Angola_International_Airport | location | Ícolo_e_Bengo', 'Angola_International_Airport | elevation | "159.106"^^xsd:double']}, {'otriple': ['Angola_International_Airport | location | Ícolo_e_Bengo', 'Angola_International_Airport | elevation | "159.0"^^xsd:double']}]
# ['Angola_International_Airport | location | Ícolo_e_Bengo', 'Angola_International_Airport | elevation | "159.0"^^xsd:double']
# ---
# [{'otriple': ['Angola_International_Airport | location | Ícolo_e_Bengo', 'Ícolo_e_Bengo | isPartOf | Luanda_Province']}, {'otriple': ['Angola_International_Airport | location | Ícolo_e_Bengo', 'Ícolo_e_Bengo | subdivisionName | Luanda_Province']}]
# ['Angola_International_Airport | location | Ícolo_e_Bengo', 'Ícolo_e_Bengo | subdivisionName | Luanda_Province']
# ---
# [{'otriple': ['Angola_International_Airport | runwayLength | "4000.0"^^xsd:double', 'Angola_International_Airport | cityServed | Luanda']}, {'otriple': ['Angola_International_Airport | runwayLength | "3999.89"^^xsd:double', 'Angola_International_Airport | cityServed | Luanda']}]
# ['Angola_International_Airport | runwayLength | "3999.89"^^xsd:double', 'Angola_International_Airport | cityServed | Luanda']
# ---
# {'otriple': ['Antwerp_International_Airport | city | Antwerp', 'Antwerp | arrondissement | Arrondissement_of_Antwerp']}
# ['Antwerp_International_Airport | city | Antwerp', 'Antwerp | arrondissement | Arrondissement_of_Antwerp']
# ---
# {'otriple': ['Antwerp_International_Airport | city | Antwerp', 'Antwerp | country | Belgium']}
# ['Antwerp_International_Airport | city | Antwerp', 'Antwerp | country | Belgium']
# ---
# {'otriple': ['Antwerp_International_Airport | city | Antwerp', 'Antwerp | mayor | Bart_De_Wever']}
# ['Antwerp_International_Airport | city | Antwerp', 'Antwerp | mayor | Bart_De_Wever']
# ---
# [{'otriple': ['Antwerp_International_Airport | operator | Flemish_Government', 'Antwerp_International_Airport | elevation | "12.0"^^xsd:double']}, {'otriple': ['Antwerp_International_Airport | operator | Flemish_Government', 'Antwerp_International_Airport | elevation | "11.8872"^^xsd:double']}]
# ['Antwerp_International_Airport | operator | Flemish_Government', 'Antwerp_International_Airport | elevation | "11.8872"^^xsd:double']
# ---
# {'otriple': ['Antwerp_International_Airport | operator | Flemish_Government', 'Antwerp_International_Airport | owner | Flemish_Region']}
# ['Antwerp_International_Airport | operator | Flemish_Government', 'Antwerp_International_Airport | owner | Flemish_Region']
# ---
# [{'otriple': ['Antwerp_International_Airport | operator | Flemish_Government', 'Antwerp_International_Airport | runwayLength | "600.151"^^xsd:double']}, {'otriple': ['Antwerp_International_Airport | operator | Flemish_Government', 'Antwerp_International_Airport | runwayLength | "600.0"^^xsd:double']}]
# ['Antwerp_International_Airport | operator | Flemish_Government', 'Antwerp_International_Airport | runwayLength | "600.0"^^xsd:double']
# ---
# {'otriple': ['Antwerp_International_Airport | operator | Flemish_Government', 'Flemish_Government | jurisdiction | Flanders']}
# ['Antwerp_International_Airport | operator | Flemish_Government', 'Flemish_Government | jurisdiction | Flanders']
# ---
# {'otriple': ['Antwerp_International_Airport | owner | Flemish_Region', 'Antwerp_International_Airport | city | Antwerp']}
# ['Antwerp_International_Airport | owner | Flemish_Region', 'Antwerp_International_Airport | city | Antwerp']
# ---
# {'otriple': ['Antwerp_International_Airport | owner | Flemish_Region', 'Antwerp_International_Airport | operator | "Flemish department of Mobility and Public Works"@en']}
# ['Antwerp_International_Airport | owner | Flemish_Region', 'Antwerp_International_Airport | operator | "Flemish department of Mobility and Public Works"@en']
# ---
# {'otriple': ['Antwerp_International_Airport | runwayLength | "1509.98"^^xsd:double', 'Antwerp_International_Airport | operator | "Flemish department of Mobility and Public Works"@en']}
# ['Antwerp_International_Airport | runwayLength | "1509.98"^^xsd:double', 'Antwerp_International_Airport | operator | "Flemish department of Mobility and Public Works"@en']
# ---
# {'otriple': ['Antwerp_International_Airport | runwayLength | "600.151"^^xsd:double', 'Antwerp_International_Airport | operator | "Flemish department of Mobility and Public Works"@en']}
# ['Antwerp_International_Airport | runwayLength | "600.151"^^xsd:double', 'Antwerp_International_Airport | operator | "Flemish department of Mobility and Public Works"@en']
# ---
# [{'otriple': ['Appleton,_Wisconsin | isPartOf | Kimberly,_Wisconsin', 'Appleton_International_Airport | cityServed | Appleton,_Wisconsin']}, {'otriple': ['Appleton,_Wisconsin | isPartOf | Kimberly,_Wisconsin', 'Appleton_International_Airport | city | Appleton,_Wisconsin']}, {'otriple': ['Appleton,_Wisconsin | subdivisionName | Kimberly,_Wisconsin', 'Appleton_International_Airport | cityServed | Appleton,_Wisconsin']}]
# ['Appleton,_Wisconsin | subdivisionName | Kimberly,_Wisconsin', 'Appleton_International_Airport | cityServed | Appleton,_Wisconsin']
# ---
# [{'otriple': ['Appleton,_Wisconsin | isPartOf | Little_Chute,_Wisconsin', 'Appleton_International_Airport | city | Appleton,_Wisconsin']}, {'otriple': ['Appleton,_Wisconsin | isPartOf | Little_Chute,_Wisconsin', 'Appleton_International_Airport | cityServed | Appleton,_Wisconsin']}, {'otriple': ['Appleton,_Wisconsin | subdivisionName | Little_Chute,_Wisconsin', 'Appleton_International_Airport | cityServed | Appleton,_Wisconsin']}]
# ['Appleton,_Wisconsin | subdivisionName | Little_Chute,_Wisconsin', 'Appleton_International_Airport | cityServed | Appleton,_Wisconsin']
# ---
# [{'otriple': ['Appleton_International_Airport | r1LengthF | 8002', 'Appleton_International_Airport | elevation | "279.806"^^xsd:double']}, {'otriple': ['Appleton_International_Airport | r1LengthF | 8002', 'Appleton_International_Airport | elevation | "280.0"^^xsd:double']}]
# ['Appleton_International_Airport | r1LengthF | 8002', 'Appleton_International_Airport | elevation | "280.0"^^xsd:double']
# ---
# [{'otriple': ['Appleton_International_Airport | elevation | "280.0"^^xsd:double', 'Appleton_International_Airport | operator | Outagamie_County,_Wisconsin']}, {'otriple': ['Appleton_International_Airport | elevation | "279.806"^^xsd:double', 'Appleton_International_Airport | operator | Outagamie_County,_Wisconsin']}]
# ['Appleton_International_Airport | elevation | "279.806"^^xsd:double', 'Appleton_International_Airport | operator | Outagamie_County,_Wisconsin']
# ---
# [{'otriple': ['Appleton_International_Airport | location | Greenville,_Wisconsin', 'Appleton_International_Airport | elevation | "280.0"^^xsd:double']}, {'otriple': ['Appleton_International_Airport | location | Greenville,_Wisconsin', 'Appleton_International_Airport | elevation | "279.806"^^xsd:double']}]
# ['Appleton_International_Airport | location | Greenville,_Wisconsin', 'Appleton_International_Airport | elevation | "279.806"^^xsd:double']
# ---
# {'otriple': ['Appleton_International_Airport | location | Greenville,_Wisconsin', 'Greenville,_Wisconsin | country | United_States']}
# ['Appleton_International_Airport | location | Greenville,_Wisconsin', 'Greenville,_Wisconsin | country | United_States']
# ---
# [{'otriple': ['Appleton_International_Airport | faa | "ATW"@en', 'Appleton_International_Airport | elevation | "280.0"^^xsd:double']}, {'otriple': ['Appleton_International_Airport | faa | "ATW"@en', 'Appleton_International_Airport | elevation | "279.806"^^xsd:double']}]
# ['Appleton_International_Airport | faa | "ATW"@en', 'Appleton_International_Airport | elevation | "279.806"^^xsd:double']
# ---
# {'otriple': ['Ardmore_Airport_(New_Zealand) | r3LengthF | 1960', 'Ardmore_Airport_(New_Zealand) | elevation | "34.0"^^xsd:double']}
# ['Ardmore_Airport_(New_Zealand) | r3LengthF | 1960', 'Ardmore_Airport_(New_Zealand) | elevation | "34.0"^^xsd:double']
# ---
# [{'otriple': ['Ardmore_Airport_(New_Zealand) | r3Surface | Poaceae', 'Ardmore_Airport_(New_Zealand) | runwayLength | "518.0"^^xsd:double']}, {'otriple': ['Ardmore_Airport_(New_Zealand) | r3Surface | Poaceae', 'Ardmore_Airport_(New_Zealand) | runwayLength | "518.16"^^xsd:double']}]
# ['Ardmore_Airport_(New_Zealand) | r3Surface | Poaceae', 'Ardmore_Airport_(New_Zealand) | runwayLength | "518.16"^^xsd:double']
# ---
# {'otriple': ['Ardmore_Airport_(New_Zealand) | r3Surface | Poaceae', 'Ardmore_Airport_(New_Zealand) | runwayDesignation | "03L/21R"']}
# ['Ardmore_Airport_(New_Zealand) | r3Surface | Poaceae', 'Ardmore_Airport_(New_Zealand) | runwayDesignation | "03L/21R"']
# ---
# {'otriple': ['Ardmore_Airport_(New_Zealand) | r3Surface | Poaceae', 'Ardmore_Airport_(New_Zealand) | runwayDesignation | "03R/21L"']}
# ['Ardmore_Airport_(New_Zealand) | r3Surface | Poaceae', 'Ardmore_Airport_(New_Zealand) | runwayDesignation | "03R/21L"']
# ---
# {'otriple': ['Ardmore_Airport_(New_Zealand) | r3Surface | Poaceae', 'Ardmore_Airport_(New_Zealand) | runwayDesignation | "07/25"']}
# ['Ardmore_Airport_(New_Zealand) | r3Surface | Poaceae', 'Ardmore_Airport_(New_Zealand) | runwayDesignation | "07/25"']
# ---
# [{'otriple': ['Ardmore_Airport_(New_Zealand) | r3Surface | Poaceae', 'Poaceae | unrankedDivisio | Flowering_plant']}, {'otriple': ['Ardmore_Airport_(New_Zealand) | r3Surface | Poaceae', 'Poaceae | division | Flowering_plant']}]
# ['Ardmore_Airport_(New_Zealand) | r3Surface | Poaceae', 'Poaceae | division | Flowering_plant']
# ---
# {'otriple': ['Ardmore_Airport_(New_Zealand) | r3Surface | Poaceae', 'Poaceae | order | Commelinids']}
# ['Ardmore_Airport_(New_Zealand) | r3Surface | Poaceae', 'Poaceae | order | Commelinids']
# ---
# {'otriple': ['Ardmore_Airport_(New_Zealand) | r3Surface | Poaceae', 'Poaceae | order | Poales']}
# ['Ardmore_Airport_(New_Zealand) | r3Surface | Poaceae', 'Poaceae | order | Poales']
# ---
# {'otriple': ['Ardmore_Airport_(New_Zealand) | location | Auckland', 'Ardmore_Airport_(New_Zealand) | operator | Civil_Aviation_Authority_of_New_Zealand']}
# ['Ardmore_Airport_(New_Zealand) | location | Auckland', 'Ardmore_Airport_(New_Zealand) | operator | Civil_Aviation_Authority_of_New_Zealand']
# ---
# {'otriple': ['Ardmore_Airport_(New_Zealand) | operator | Civil_Aviation_Authority_of_New_Zealand', 'Civil_Aviation_Authority_of_New_Zealand | location | Wellington']}
# ['Ardmore_Airport_(New_Zealand) | operator | Civil_Aviation_Authority_of_New_Zealand', 'Civil_Aviation_Authority_of_New_Zealand | location | Wellington']
# ---
# [{'otriple': ['Ardmore_Airport_(New_Zealand) | runwayLength | "1411.22"^^xsd:double', 'Ardmore_Airport_(New_Zealand) | r3Surface | Poaceae']}, {'otriple': ['Ardmore_Airport_(New_Zealand) | runwayLength | "1411.0"^^xsd:double', 'Ardmore_Airport_(New_Zealand) | r3Surface | Poaceae']}]
# ['Ardmore_Airport_(New_Zealand) | runwayLength | "1411.0"^^xsd:double', 'Ardmore_Airport_(New_Zealand) | r3Surface | Poaceae']
# ---
# [{'otriple': ['Ashgabat_International_Airport | r3LengthF | 2953', 'Ashgabat_International_Airport | elevation | "210.922"^^xsd:double']}, {'otriple': ['Ashgabat_International_Airport | r3LengthF | 2953', 'Ashgabat_International_Airport | elevation | "211.0"^^xsd:double']}]
# ['Ashgabat_International_Airport | r3LengthF | 2953', 'Ashgabat_International_Airport | elevation | "211.0"^^xsd:double']
# ---
# [{'otriple': ['Ashgabat_International_Airport | icaoLocationIdentifier | "(Location of airport in Turkmenistan)"', 'Ashgabat_International_Airport | iataLocationIdentifier | "ASB"']}, {'otriple': ['Ashgabat_International_Airport | iataLocationIdentifier | "ASB"', 'Ashgabat_International_Airport | icaoLocationIdentifier | "UTAA"']}]
# ['Ashgabat_International_Airport | iataLocationIdentifier | "ASB"', 'Ashgabat_International_Airport | icaoLocationIdentifier | "UTAA"']
# ---
# [{'otriple': ['Ashgabat_International_Airport | location | Ashgabat', 'Ashgabat_International_Airport | elevation | "210.922"^^xsd:double']}, {'otriple': ['Ashgabat_International_Airport | location | Ashgabat', 'Ashgabat_International_Airport | elevation | "211.0"^^xsd:double']}]
# ['Ashgabat_International_Airport | location | Ashgabat', 'Ashgabat_International_Airport | elevation | "211.0"^^xsd:double']
# ---
# [{'otriple': ['Ashgabat_International_Airport | operator | Turkmenistan_Airlines', 'Ashgabat_International_Airport | elevation | "210.922"^^xsd:double']}, {'otriple': ['Ashgabat_International_Airport | operator | Turkmenistan_Airlines', 'Ashgabat_International_Airport | elevation | "211.0"^^xsd:double']}]
# ['Ashgabat_International_Airport | operator | Turkmenistan_Airlines', 'Ashgabat_International_Airport | elevation | "211.0"^^xsd:double']
# ---
# [{'otriple': ['Ashgabat_International_Airport | operator | Turkmenistan_Airlines', 'Turkmenistan_Airlines | headquarter | Ashgabat']}, {'otriple': ['Ashgabat_International_Airport | operator | Turkmenistan_Airlines', 'Turkmenistan_Airlines | headquarters | Ashgabat']}]
# ['Ashgabat_International_Airport | operator | Turkmenistan_Airlines', 'Turkmenistan_Airlines | headquarters | Ashgabat']
# ---
# {'otriple': ['Ashgabat_International_Airport | operator | Turkmenistan_Airlines', 'Turkmenistan_Airlines | targetAirport | Turkmenabat_Airport']}
# ['Ashgabat_International_Airport | operator | Turkmenistan_Airlines', 'Turkmenistan_Airlines | targetAirport | Turkmenabat_Airport']
# ---
# {'otriple': ['Ashgabat_International_Airport | operator | Turkmenistan_Airlines', 'Turkmenistan_Airlines | targetAirport | Turkmenbashi_International_Airport']}
# ['Ashgabat_International_Airport | operator | Turkmenistan_Airlines', 'Turkmenistan_Airlines | targetAirport | Turkmenbashi_International_Airport']
# ---
# {'otriple': ['Ashgabat_International_Airport | runwayLength | "2988.87"^^xsd:double', 'Ashgabat_International_Airport | location | Ashgabat']}
# ['Ashgabat_International_Airport | runwayLength | "2988.87"^^xsd:double', 'Ashgabat_International_Airport | location | Ashgabat']
# ---
# [{'otriple': ['Athens_International_Airport | cityServed | Athens', 'Athens | mayor | Giorgos_Kaminis']}, {'otriple': ['Athens | mayor | Giorgos_Kaminis', 'Athens_International_Airport | city | Athens']}]
# ['Athens | mayor | Giorgos_Kaminis', 'Athens_International_Airport | city | Athens']
# ---
# [{'otriple': ['Athens | country | Greece', 'Athens_International_Airport | city | Athens']}, {'otriple': ['Athens_International_Airport | cityServed | Athens', 'Athens | country | Greece']}]
# ['Athens_International_Airport | cityServed | Athens', 'Athens | country | Greece']
# ---
# [{'otriple': ['Athens_International_Airport | city | Athens', 'Athens_International_Airport | runwayLength | "3999.89"^^xsd:double']}, {'otriple': ['Athens_International_Airport | cityServed | Athens', 'Athens_International_Airport | runwayLength | "3999.89"^^xsd:double']}, {'otriple': ['Athens_International_Airport | city | Athens', 'Athens_International_Airport | runwayLength | "4000.0"^^xsd:double']}, {'otriple': ['Athens_International_Airport | cityServed | Athens', 'Athens_International_Airport | runwayLength | "4000.0"^^xsd:double']}]
# ['Athens_International_Airport | cityServed | Athens', 'Athens_International_Airport | runwayLength | "4000.0"^^xsd:double']
# ---
# [{'otriple': ['Athens_International_Airport | location | Spata', 'Athens_International_Airport | elevation | "94.0"^^xsd:double']}, {'otriple': ['Athens_International_Airport | location | Spata', 'Athens_International_Airport | elevation | "93.8784"^^xsd:double']}]
# ['Athens_International_Airport | location | Spata', 'Athens_International_Airport | elevation | "93.8784"^^xsd:double']
# ---
# [{'otriple': ['Atlantic_City_International_Airport | city | Atlantic_City,_New_Jersey', 'Atlantic_City,_New_Jersey | leaderName | Don_Guardian']}, {'otriple': ['Atlantic_City_International_Airport | cityServed | Atlantic_City,_New_Jersey', 'Atlantic_City,_New_Jersey | leaderName | Don_Guardian']}]
# ['Atlantic_City_International_Airport | cityServed | Atlantic_City,_New_Jersey', 'Atlantic_City,_New_Jersey | leaderName | Don_Guardian']
# ---
# [{'otriple': ['Atlantic_City_International_Airport | location | Egg_Harbor_Township,_New_Jersey', 'Egg_Harbor_Township,_New_Jersey | subdivisionName | Atlantic_County,_New_Jersey']}, {'otriple': ['Atlantic_City_International_Airport | location | Egg_Harbor_Township,_New_Jersey', 'Egg_Harbor_Township,_New_Jersey | isPartOf | Atlantic_County,_New_Jersey']}]
# ['Atlantic_City_International_Airport | location | Egg_Harbor_Township,_New_Jersey', 'Egg_Harbor_Township,_New_Jersey | isPartOf | Atlantic_County,_New_Jersey']
# ---
# {'otriple': ['Atlantic_City_International_Airport | operator | Port_Authority_of_New_York_and_New_Jersey', 'Atlantic_City_International_Airport | elevation | "22.86"^^xsd:double']}
# ['Atlantic_City_International_Airport | operator | Port_Authority_of_New_York_and_New_Jersey', 'Atlantic_City_International_Airport | elevation | "22.86"^^xsd:double']
# ---
# [{'otriple': ['Atlantic_City_International_Airport | operator | "Port Authority of New York and New Jersey & SJTA"@en', 'Atlantic_City_International_Airport | runwayDesignation | "13/31"']}, {'otriple': ['Atlantic_City_International_Airport | operator | Port_Authority_of_New_York_and_New_Jersey', 'Atlantic_City_International_Airport | runwayDesignation | "13/31"']}]
# ['Atlantic_City_International_Airport | operator | Port_Authority_of_New_York_and_New_Jersey', 'Atlantic_City_International_Airport | runwayDesignation | "13/31"']
# ---
# {'otriple': ['Atlantic_City_International_Airport | operator | Port_Authority_of_New_York_and_New_Jersey', 'Port_Authority_of_New_York_and_New_Jersey | headquarter | Four_World_Trade_Center']}
# ['Atlantic_City_International_Airport | operator | Port_Authority_of_New_York_and_New_Jersey', 'Port_Authority_of_New_York_and_New_Jersey | headquarter | Four_World_Trade_Center']
# ---
# {'otriple': ['Atlantic_City_International_Airport | operator | Port_Authority_of_New_York_and_New_Jersey', 'Port_Authority_of_New_York_and_New_Jersey | headquarter | New_York']}
# ['Atlantic_City_International_Airport | operator | Port_Authority_of_New_York_and_New_Jersey', 'Port_Authority_of_New_York_and_New_Jersey | headquarter | New_York']
# ---
# {'otriple': ['Atlantic_City_International_Airport | owner | South_Jersey_Transportation_Authority', 'South_Jersey_Transportation_Authority | chief1Name | Stephen_Dilts']}
# ['Atlantic_City_International_Airport | owner | South_Jersey_Transportation_Authority', 'South_Jersey_Transportation_Authority | chief1Name | Stephen_Dilts']
# ---
# {'otriple': ['Atlantic_City_International_Airport | owner | South_Jersey_Transportation_Authority', 'South_Jersey_Transportation_Authority | leader | Stephen_Dilts']}
# ['Atlantic_City_International_Airport | owner | South_Jersey_Transportation_Authority', 'South_Jersey_Transportation_Authority | leader | Stephen_Dilts']
# ---
# [{'otriple': ['Atlantic_City_International_Airport | runwayLength | "1873.0"^^xsd:double', 'Atlantic_City_International_Airport | operator | "Port Authority of New York and New Jersey & SJTA"@en']}, {'otriple': ['Atlantic_City_International_Airport | runwayLength | "1873.0"^^xsd:double', 'Atlantic_City_International_Airport | operator | Port_Authority_of_New_York_and_New_Jersey']}, {'otriple': ['Atlantic_City_International_Airport | runwayLength | "1872.69"^^xsd:double', 'Atlantic_City_International_Airport | operator | "Port Authority of New York and New Jersey & SJTA"@en']}, {'otriple': ['Atlantic_City_International_Airport | runwayLength | "1872.69"^^xsd:double', 'Atlantic_City_International_Airport | operator | Port_Authority_of_New_York_and_New_Jersey']}]
# ['Atlantic_City_International_Airport | runwayLength | "1872.69"^^xsd:double', 'Atlantic_City_International_Airport | operator | Port_Authority_of_New_York_and_New_Jersey']
# ---
# {'otriple': ['ENAIRE | locationCity | Madrid', 'Adolfo_Suárez_Madrid–Barajas_Airport | operator | ENAIRE']}
# ['ENAIRE | locationCity | Madrid', 'Adolfo_Suárez_Madrid–Barajas_Airport | operator | ENAIRE']
# ---
# {'otriple': ['Egg_Harbor_Township,_New_Jersey | isPartOf | New_Jersey', 'Atlantic_City_International_Airport | location | Egg_Harbor_Township,_New_Jersey']}
# ['Egg_Harbor_Township,_New_Jersey | isPartOf | New_Jersey', 'Atlantic_City_International_Airport | location | Egg_Harbor_Township,_New_Jersey']
# ---
# {'otriple': ['Flemish_Government | jurisdiction | Flemish_Region', 'Antwerp_International_Airport | operator | Flemish_Government']}
# ['Flemish_Government | jurisdiction | Flemish_Region', 'Antwerp_International_Airport | operator | Flemish_Government']
# ---
# {'otriple': ['Indian_Air_Force | aircraftHelicopter | HAL_Light_Combat_Helicopter', 'Agra_Airport | operator | Indian_Air_Force']}
# ['Indian_Air_Force | aircraftHelicopter | HAL_Light_Combat_Helicopter', 'Agra_Airport | operator | Indian_Air_Force']
# ---
# [{'otriple': ['Lahore | country | Pakistan', 'Allama_Iqbal_International_Airport | cityServed | Lahore']}, {'otriple': ['Allama_Iqbal_International_Airport | city | Lahore', 'Lahore | country | Pakistan']}]
# ['Allama_Iqbal_International_Airport | city | Lahore', 'Lahore | country | Pakistan']
# ---
# [{'otriple': ['Lake_Placid,_New_York | isPartOf | Essex_County,_New_York', 'Adirondack_Regional_Airport | city | Lake_Placid,_New_York']}, {'otriple': ['Lake_Placid,_New_York | isPartOf | Essex_County,_New_York', 'Adirondack_Regional_Airport | cityServed | Lake_Placid,_New_York']}]
# ['Lake_Placid,_New_York | isPartOf | Essex_County,_New_York', 'Adirondack_Regional_Airport | cityServed | Lake_Placid,_New_York']
# ---
# [{'otriple': ['Lake_Placid,_New_York | isPartOf | New_York', 'Adirondack_Regional_Airport | city | Lake_Placid,_New_York']}, {'otriple': ['Lake_Placid,_New_York | isPartOf | New_York', 'Adirondack_Regional_Airport | cityServed | Lake_Placid,_New_York']}]
# ['Lake_Placid,_New_York | isPartOf | New_York', 'Adirondack_Regional_Airport | cityServed | Lake_Placid,_New_York']
# ---
# {'otriple': ['Madrid | isPartOf | Community_of_Madrid', 'Adolfo_Suárez_Madrid–Barajas_Airport | location | Madrid']}
# ['Madrid | isPartOf | Community_of_Madrid', 'Adolfo_Suárez_Madrid–Barajas_Airport | location | Madrid']
# ---
# {'otriple': ['Maple_Ridge_Township,_Alpena_County,_Michigan | subdivisionName | United_States', 'Alpena_County_Regional_Airport | location | Maple_Ridge_Township,_Alpena_County,_Michigan']}
# ['Maple_Ridge_Township,_Alpena_County,_Michigan | subdivisionName | United_States', 'Alpena_County_Regional_Airport | location | Maple_Ridge_Township,_Alpena_County,_Michigan']
# ---
# {'otriple': ['Poaceae | class | Monocotyledon', 'Ardmore_Airport_(New_Zealand) | r2Surface | Poaceae']}
# ['Poaceae | class | Monocotyledon', 'Ardmore_Airport_(New_Zealand) | r2Surface | Poaceae']
# ---
# {'otriple': ['Poaceae | division | Flowering_plant', 'Alderney_Airport | r1Surface | Poaceae']}
# ['Poaceae | division | Flowering_plant', 'Alderney_Airport | r1Surface | Poaceae']
# ---
# {'otriple': ['Poaceae | division | Flowering_plant', 'Ardmore_Airport_(New_Zealand) | r2Surface | Poaceae']}
# ['Poaceae | division | Flowering_plant', 'Ardmore_Airport_(New_Zealand) | r2Surface | Poaceae']
# ---
# {'otriple': ['Poaceae | order | Commelinids', 'Ardmore_Airport_(New_Zealand) | r2Surface | Poaceae']}
# ['Poaceae | order | Commelinids', 'Ardmore_Airport_(New_Zealand) | r2Surface | Poaceae']
# ---
# [{'otriple': ['Saranac_Lake,_New_York | isPartOf | Essex_County,_New_York', 'Adirondack_Regional_Airport | city | Saranac_Lake,_New_York']}, {'otriple': ['Saranac_Lake,_New_York | isPartOf | Essex_County,_New_York', 'Adirondack_Regional_Airport | cityServed | Saranac_Lake,_New_York']}]
# ['Saranac_Lake,_New_York | isPartOf | Essex_County,_New_York', 'Adirondack_Regional_Airport | cityServed | Saranac_Lake,_New_York']
# ---
# [{'otriple': ['Saranac_Lake,_New_York | isPartOf | Harrietstown,_New_York', 'Adirondack_Regional_Airport | city | Saranac_Lake,_New_York']}, {'otriple': ['Saranac_Lake,_New_York | isPartOf | Harrietstown,_New_York', 'Adirondack_Regional_Airport | cityServed | Saranac_Lake,_New_York']}, {'otriple': ['Saranac_Lake,_New_York | subdivisionName | Harrietstown,_New_York', 'Adirondack_Regional_Airport | cityServed | Saranac_Lake,_New_York']}]
# ['Saranac_Lake,_New_York | subdivisionName | Harrietstown,_New_York', 'Adirondack_Regional_Airport | cityServed | Saranac_Lake,_New_York']
# ---
# {'otriple': ['Saranac_Lake,_New_York | subdivisionName | United_States', 'Adirondack_Regional_Airport | cityServed | Saranac_Lake,_New_York']}
# ['Saranac_Lake,_New_York | subdivisionName | United_States', 'Adirondack_Regional_Airport | cityServed | Saranac_Lake,_New_York']
# ---
